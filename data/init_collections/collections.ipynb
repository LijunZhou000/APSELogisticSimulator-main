# %%
import pymongo
import faker
import json
from bson import ObjectId
import hashlib

# %%
# !pip install [biblio]

# %%
# Connect to the MongoDB with user and password
db = pymongo.MongoClient("mongodb://localhost:27018/")["simulator"]

# %%
from bson import json_util

# %%
json_util.dumps(pymongo.MongoClient("mongodb://localhost:27018/")["simulator"]["locations"].find())
# Out:
# '[{"_id": {"$oid": "ce6feed06bc1a9e5aff95f04"}, "name": "plaza del Dos de Mayo, 6, Madrid", "coordinates": {"longitude": -3.7041862522159366, "latitude": 40.42732576700565}}, {"_id": {"$oid": "47700194cae2115edbe89387"}, "name": "calle de R\\u00edos Rosas, 50, Madrid", "coordinates": {"longitude": -3.6962344605258637, "latitude": 40.44159015809918}}, {"_id": {"$oid": "065e50ccf9bed218e4dc14c6"}, "name": "calle de Argensola, 12, Madrid", "coordinates": {"longitude": -3.694781349065569, "latitude": 40.42528356625323}}, {"_id": {"$oid": "e19049464a9467a9a95402ed"}, "name": "calle de Alcal\\u00e1, 98, Madrid", "coordinates": {"longitude": -3.67484420244431, "latitude": 40.42499625549617}}, {"_id": {"$oid": "a5f240a9777e72c31a3e69d2"}, "name": "plaza de Salesas, 7, Madrid", "coordinates": {"longitude": -3.694447144937114, "latitude": 40.42373602046807}}, {"_id": {"$oid": "94a4877361dfc7ba1b87cab4"}, "name": "calle de Leopoldo Alas Clar\\u00edn, 8, Madrid", "coordinates": {"longitude": -3.7335507127210215, "latitude": 40.48033217152688}}, {"_id": {"$oid": "15937de4acb61e0a344c6f40"}, "name": "calle C\\u00e1ceres, 5, San Fernando de Henares", "coordinates": {"longitude": -3.534354949036296, "latitude": 40.427154383748515}}, {"_id": {"$oid": "683d492beb28f2b6843fdc25"}, "name": "gta de L\\u00f3pez de Hoyos, 3, Madrid", "coordinates": {"longitude": -3.6806280562952987, "latitude": 40.440944359155}}, {"_id": {"$oid": "d9cdbdb0da78a71c66b30271"}, "name": "calle del Valle de Mena, 4, Madrid", "coordinates": {"longitude": -3.715108586690274, "latitude": 40.470159531466635}}, {"_id": {"$oid": "2c9d3210eab39a36e1f2e21b"}, "name": "calle del Pr\\u00edncipe de Vergara, 210, Madrid", "coordinates": {"longitude": -3.6773815640693885, "latitude": 40.45112558610754}}, {"_id": {"$oid": "27f95bc631a2522868c52b82"}, "name": "calle del General Pardi\\u00f1as, 61, Madrid", "coordinates": {"longitude": -3.6782259574180807, "latitude": 40.43188639394151}}, {"_id": {"$oid": "066eeaec0b80ec50d05f58fa"}, "name": "calle Vel\\u00e1zquez, 2, Loeches", "coordinates": {"longitude": -3.40981023623125, "latitude": 40.38320286883676}}, {"_id": {"$oid": "b1d80a9ed76950ed2b486c8c"}, "name": "calle de Gutenberg, 20, Madrid", "coordinates": {"longitude": -3.6803296886464514, "latitude": 40.40665771373414}}, {"_id": {"$oid": "3647bfc67b4b0b796cf02915"}, "name": "calle de Preciados, 19, Madrid", "coordinates": {"longitude": -3.7054552895656787, "latitude": 40.41902972072887}}, {"_id": {"$oid": "445701b5f805c76588b9bd89"}, "name": "calle del Alcalde Henche de la Plata, 7, Madrid", "coordinates": {"longitude": -3.6498733753583856, "latitude": 40.48833743115443}}, {"_id": {"$oid": "80fd8dd40249feffc88145a0"}, "name": "calle de Ponzano, 31, Madrid", "coordinates": {"longitude": -3.69940710800667, "latitude": 40.43939082671233}}, {"_id": {"$oid": "73ac662a164ad65152e57271"}, "name": "avda General, 1, Madrid", "coordinates": {"longitude": -3.577826245886988, "latitude": 40.47327871193892}}, {"_id": {"$oid": "8bc8213782336471754e8990"}, "name": "paseo de Santa Mar\\u00eda de la Cabeza, 80, Madrid", "coordinates": {"longitude": -3.701578671987521, "latitude": 40.398737890321556}}, {"_id": {"$oid": "eef6c322fa22198aba0c124e"}, "name": "calle de Rodr\\u00edguez San Pedro, 23, Madrid", "coordinates": {"longitude": -3.7110570692810603, "latitude": 40.431608042104514}}, {"_id": {"$oid": "85ed504d7134f0484437eca6"}, "name": "calle de Feijoo, 12, Madrid", "coordinates": {"longitude": -3.7031549248067317, "latitude": 40.43470142324421}}, {"_id": {"$oid": "c607448f690edbe3e4451bbd"}, "name": "calle de Diego de Le\\u00f3n, 34, Madrid", "coordinates": {"longitude": -3.6813429296322813, "latitude": 40.43466987218751}}, {"_id": {"$oid": "58a50ddf91095c052e330fd6"}, "name": "calle Madrid, 48, Getafe", "coordinates": {"longitude": -3.7296081336415634, "latitude": 40.307662279160645}}, {"_id": {"$oid": "1793fd9ee539dc62a736ead0"}, "name": "calle de Juan Zof\\u00edo, 4, Madrid", "coordinates": { ...

# %%
# Create a fake truck data generator
faker.Faker.seed(42)

fake = faker.Faker("es_ES")
trucks = db["trucks"]
#drop the collection
trucks.drop()
for i in range(20):
    truck = {
        "id": fake.license_plate_unified().replace(" ", ""),
        "capacity": fake.random_int(min=10, max=30)
    }
    trucks.insert_one(truck)

# %%
def create_object_id(string):
    hashed = hashlib.sha1(string.encode()).hexdigest()
    object_id = ObjectId(hashed[:24])
    return object_id

# %%
locations = db["locations"]
#drop the collection
locations.drop()
farmacias = json.load(open("../farmacias/farmacias.json", "r"))
#filter farmacias with no coordinates
farmacias = [farmacia for farmacia in farmacias if farmacia["coordinates"] is not None and farmacia["coordinates"]["latitude"] is not None and farmacia["coordinates"]["longitude"] is not None]
# eliminate farmacias with no name or duplicate names
farmacias = {farmacia["name"]: farmacia for farmacia in farmacias}.values()

#add _id
for farmacia in farmacias:
    farmacia["_id"] = create_object_id(farmacia["name"])

locations.insert_many(farmacias)
# Out:
), ObjectId('0913ab0f37483bf2b1a72664'), ObjectId('fc2ed51a65e1473d8a2859ba'), ObjectId('98049c471fe77a402c0c6379'), ObjectId('41281062b5a24b7992044395'), ObjectId('02daa212163f72d7d2dc4414'), ObjectId('5fc2eee69e4f20f94c2b5420'), ObjectId('c2eb1c63b5b1bb28d06cefaa'), ObjectId('48adbff1f97846a7edab59fa'), ObjectId('a239f00794af715bfd7e46fa'), ObjectId('16a2059695eafcb136ef82c6'), ObjectId('37dc73679e27ac764b7ec239'), ObjectId('170102a9423ffeaaa1ee5030'), ObjectId('365fbe107af15482ce1be1b6'), ObjectId('3b9fbf2b7ce0abfdcdffaf59'), ObjectId('fb5eea977c41f42554288102'), ObjectId('5c3ddcb22a95f99fe3d9a416'), ObjectId('0f4c8b0654e27608c500e311'), ObjectId('99ce67ade13e4d0b896717a7'), ObjectId('4e74c630d560930836983338'), ObjectId('db0e60e6037c08ce560d731d'), ObjectId('01c0ec606d7d4caa083f6d5f'), ObjectId('454935aa7a63afa5b9f8f62a'), ObjectId('8b651f9ef79ad0b6f2d6b4c5'), ObjectId('0931dc706267b6e5a28c915f'), ObjectId('96ab5d20b4b823cb40e5662f'), ObjectId('d72a324be8de57a8f34831c0'), ObjectId('8006b61e975fda65032499a8'), ObjectId('efb85de16cb5f0a396057f58'), ObjectId('9abdf4c45a8cfb3a3dab3566'), ObjectId('d41e99d132831b14f7fee010'), ObjectId('7cbc6a22d00a737375edcb63'), ObjectId('e43817eb219a05b466249117'), ObjectId('9deafec95aa36255db214ba6'), ObjectId('1d6f151cbc3ecac009f87a09'), ObjectId('4d205f32a9d12c681fcb ...

# %%
# plot al the locations in a map
import folium

m = folium.Map(location=[40.416775, -3.703790], zoom_start=9)
for farmacia in farmacias:
    folium.Marker([farmacia["coordinates"]["latitude"], farmacia["coordinates"]["longitude"]], popup=farmacia["name"]).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8f78fa65f199d0d7563980bd1b3373df {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8f78fa65f199d0d7563980bd1b3373df&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8f78fa65f199d0d7563980bd1b3373df = L.map(
#                 &quot;map_8f78fa65f199d0d7563980bd1b3373df&quot;,
#                 {
#                     center: [40.416775, -3.70379],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8433e7b64903add0ef6a5ee0943f8adb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8433e7b64903add0ef6a5ee0943f8adb.addTo(map_8f78fa65f199d0d7563980bd1b3373df);
#
#
#             var marker_a0ea3e2da1da1659d28caf4326fcf71a = L.marker(
#                 [40.42732576700565, -3.7041862522159366],
#                 {
# }
#             ).addTo(map_8f78fa65f199d0d7563980bd1b3373df);
#
#
#         var popup_fea5dc2884bc76e17e712f3dd722c317 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b17f9009f11990fbefcf957dd2bf8b83 = $(`&lt;div id=&quot;html_b17f9009f11990fbefcf957dd2bf8b83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;plaza del Dos de Mayo, 6, Madrid&lt;/div&gt;`)[0];
#                 popup_fea5dc2884bc76e17e712f3dd722c317.setContent(html_b17f9009f11990fbefcf957dd2bf8b83);
#
#
#
#         marker_a0ea3e2da1da1659d28caf4326fcf71a.bindPopup(popup_fea5dc2884bc76e17e712f3dd722c317)
#         ;
#
#
#
#
#             var marker_722666e634e190e317811f678f284097 = L.marker(
#                 [40.44159015809918, -3.6962344605258637],
#                 {
# }
#             ).addTo(map_8f78fa65f199d0d7563980bd1b3373df);
#
#
#         var popup_2e2f06fe52b05d1e12bf346f0aa04aa9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef7660b301e859cdde8561093b3d2182 = $(`&lt;div id=&quot;html_ef7660b301e859cdde8561093b3d2182&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;calle de Ríos Rosas, 50, Madrid&lt;/div&gt;`)[0];
#                 popup_2e2f06fe52b05d1e12bf346f0aa04aa9.setContent(html_ef7660b301e859cdde8561093b3d2182);
#
#
#
#         marker_722666e634e190e317811f678f284097.bindPopup(popup_2e2f06fe52b05d1e12bf346f0aa04aa9)
#         ;
#
#
#
#
#             var marker_9521ae1ccdd834b49e0287c3fb30fd16 = L.marker(
#                 [40.42528356625323, -3.694781349065569],
#                 {
# }
#             ).addTo(map_8f78fa65f199d0d7563980bd1b3373df);
#
#
#         var popup_081255ebb3141dd4754f99e2515115a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c80f5e910b48a5b1edd6ac93d187990 = $(`&lt;div id=&quot;html_5c80f5e910b48a5b1edd6ac93d187990&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;calle de Argensola, 12, Madrid&lt;/div&gt;`)[0];
#                 popup_081255ebb3141dd4754f99e2515115a7.setContent(html_5c80f5e910b48a5b1edd6ac93d187990);
#
#
#
#         marker_9521ae1ccdd834b49e0287c3fb30fd16.bindPopup(popup_081255ebb3141dd4754f99e2515115a7)
#         ;
#
#
#
#
#             var marker_00202e2ddba16474664a05f35ba37dc9 = L.marker(
#                 [40.42499625549617, -3.67484420244431],
#                 {
# }
#             ).addTo(map_8f78fa65f199d0d7563980bd1b3373df);
#
#
#         var popup_85ca6228ded728163a6d98b6c532b740 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1c3e75d42f2dd1d9e35d3c4eaad8aaa = $(`&lt;div id=&quot;html_c1c3e75d42f2dd1d9e35d3c4eaad8aaa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;calle de Alcalá, 98, Madrid&lt;/div&gt;`)[0];
#                 popup_85ca6228ded728163a6d98b6c532b740.setContent(html_c1c3e75d42f2dd1d9e35d3c4eaad8aaa);
#
#
#
#         marker_00202e2ddba16474664a05f35ba37dc9.bindPopup(popup_85ca6228ded728163a6d98b6c532b740)
#         ;
#
#
#
#
#             var marker_e8d2cb11a4aabc88f57e17f464ac3403 = L.marker(
#                 [40.42373602046807, -3.694447144937114],
#                 {
# }
#             ).addTo(map_8f78fa65f199d0d7563980bd1b3373df);
#
#
#         var popup_caa7cce308e2276da49d96974788b40f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7217a88fb4c6a5f69bfcf4c6dd137552 = $(`&lt;div id=&quot;html_7217a88fb4c6a5f69bfcf4c6dd137552&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;plaza de Salesas, 7, Madrid&lt;/div&gt;`)[0];
#                 popup_caa7cce308e2276da49d96974788b40f.setContent(html_7217a88fb4c6a5f69bfcf4c6dd137552);
#
#
#
#         marker_e8d2cb11a4aabc88f57e17f464ac3403.bindPopup(popup_caa7cce308e2276da49d9
