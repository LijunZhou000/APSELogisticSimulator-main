# %%
import pymongo
from bson import json_util
import pandas as pd

# %%
db = pymongo.MongoClient("mongodb://localhost:27018/")["simulator"]["plans"]

# %%
pd.read_json(json_util.dumps(db.find({"trucks.truck_id": "3953RLD", "simulationId": "faad72e6-24fd-4160-afc8-aba5ea503c9a"})))
# Out:
# C:\Users\LIJUN\AppData\Local\Temp\ipykernel_25296\1497749394.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_json(json_util.dumps(db.find({"trucks.truck_id": "3953RLD", "simulationId": "faad72e6-24fd-4160-afc8-aba5ea503c9a"})))
#                                     _id  \
# 0  {'$oid': '67d00161c5f9ba78953f5b1e'}
#
#                                               trucks  \
# 0  [{'items': ['6', '2', '3'], 'route': [{'origin...
#
#                                                items  \
# 0  [{'locationId': '0c293316d52cc68441c79921', 'i...
#
#                            simulationId
# 0  faad72e6-24fd-4160-afc8-aba5ea503c9a
